# %%
import pandas as pd
import numpy as np
imdb1 = pd.read_csv('imdb.csv')
imdb1_df = pd.DataFrame(imdb1)
imdb1_df.sort_values(by='rate', ascending =False,ignore_index=True, inplace= True)
imdb1_df
# Out:
#     country               date              director  \
# 0       USA   14 October 1994         Frank Darabont
# 1       USA     24 March 1972   Francis Ford Coppola
# 2       USA  18 December 1974   Francis Ford Coppola
# 3       USA      18 July 2008      Christopher Nolan
# 4       USA   14 October 1994      Quentin Tarantino
# ..      ...                ...                   ...
# 313  Turkey  26 December 2015           Furkan Kopuz
# 314     USA  17 December 2014          Peter Jackson
# 315     USA       24 May 2002      Christopher Nolan
# 316     USA     25 April 2012            Faruk Aksoy
# 317  Turkey       19 May 2013           Furkan Kopuz
#
#                                           film  rate  \
# 0                     The Shawshank Redemption   9.3
# 1                                The Godfather   9.2
# 2                       The Godfather: Part II   9.0
# 3                              The Dark Knight   9.0
# 4                                 Pulp Fiction   8.9
# ...
